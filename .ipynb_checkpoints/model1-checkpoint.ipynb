# %%
import numpy as np
import datetime
import pandas as pd
import seaborn as sns
import time as t
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import make_column_selector as selector
from sklearn.ensemble import AdaBoostClassifier
from Pre_processing import *
import pickle
from dython.nominal import associations
from sklearn.metrics import r2_score

# %%
# dbfile = open('Regression_model', 'rb')     
# db = pickle.load(dbfile)
# dbfile.close()
# print(db.keys())
# model1 = db['model1']
# model2 = db['model2']

# %%
#Read data from file #
def getData(path):
    data = pd.read_csv(path)
    temp = []
    for i in data['national_team']:
        if type(i) != str:
            value = '0'
        else:
            value = '1'
        temp.append(value)
    data['national_team'] = temp
    
    return data
data = getData('player-value-prediction.csv')



mean_mode = get_mode_means(data)

# %%
mean_mode
# Out:
# {'id': 215308.41056882267,
#  'name': 0    J. Rodríguez
#  dtype: object,
#  'full_name': 0    Adama Traoré
#  1     Scott Brown
#  dtype: object,
#  'birth_date': 0    2/29/1992
#  dtype: object,
#  'age': 25.575367263106592,
#  'height_cm': 174.90206920556963,
#  'weight_kgs': 75.30426791060502,
#  'positions': 0    CB
#  dtype: object,
#  'nationality': 0    England
#  dtype: object,
#  'overall_rating': 66.25767597298615,
#  'potential': 71.4353547309058,
#  'wage': 9888.37143663562,
#  'preferred_foot': 0    Right
#  dtype: object,
#  'international_reputation(1-5)': 1.1107011070110702,
#  'weak_foot(1-5)': 2.9467381466267493,
#  'skill_moves(1-5)': 2.3585601893754786,
#  'work_rate': 0    Medium/ Medium
#  dtype: object,
#  'body_type': 0    Normal
#  dtype: object,
#  'release_clause_euro': 4622436.456796832,
#  'club_team': 0           AS Monaco
#  1    Newcastle United
#  2            RC Celta
#  dtype: object,
#  'club_rating': 69.3698696954916,
#  'club_position': 0    SUB
#  dtype: object,
#  'club_jersey_number': 20.295240749773534,
#  'club_join_date': 0    7/1/2018
#  dtype: object,
#  'contract_end_year': 0    2021
#  dtype: object,
#  'national_team': 0    0
#  dtype: object,
#  'national_rating': 76.30232558139535,
#  'national_team_position': 0    SUB
#  dtype: object,
#  'national_jersey_number': 12.396802325581396,
#  'crossing': 49.73208939636566,
#  'finishing': 45.34735083199889,
#  'heading_accuracy': 52.101232333078045,
#  'short_passing': 58.54424563113556,
#  'volleys': 42.691847107150316,
#  'dribbling': 55.25384668941029,
#  'curve': 47.088839378959825,
#  'freekick_accuracy': 42.66908027570842,
#  'long_passing': 52.66490287544385,
#  'ball_control': 58.19292626888533,
#  'acceleration': 64.64735779433266,
#  'sprint_speed': 64.75896400473438,
#  'agility': 63.33454013785421,
#  'reactions': 61.86701942491123,
#  'balance': 63.87788066559911,
#  'shot_power': 55.27835410429576,
#  'jumping': 64.91512915129151,
#  'stamina': 63.10255517649516,
#  'strength': 65.17036830745666,
#  'long_shots': 46.834783819536305,
#  'aggression': 55.81417531156443,
#  'interceptions': 46.62382510617559,
#  'positioning': 49.8261505256562,
#  'vision': 53.3942073382998,
#  'penalties': 48.35424354243543,
#  'composure': 58.680846619786955,
#  'marking': 47.091206572443085,
#  'standing_tackle': 47.676460349509156,
#  'sliding_tackle': 45.678618672979184,
#  'GK_diving': 16.84153728329736,
#  'GK_handling': 16.62110979600362,
#  'GK_kicking': 16.431246953978974,
#  'GK_positioning': 16.595558031052008,
#  'GK_reflexes': 16.95244726032166,
#  'tags': 0    #Strength
#  dtype: object,
#  'traits': 0    Speed Dribbler (CPU AI Only)
#  dtype: object,
#  'LS': 0    64+2
#  dtype: object,
#  'ST': 0    64+2
#  dtype: object,
#  'RS': 0    64+2
#  dtype: object,
#  'LW': 0    63+2
#  dtype: object,
#  'LF': 0    62+2
#  dtype: object,
#  'CF': 0    62+2
#  dtype: object,
#  'RF': 0    62+2
#  dtype: object,
#  'RW': 0    63+2
#  dtype: object,
#  'LAM': 0    61+2
#  dtype: object,
#  'CAM': 0    61+2
#  dtype: object,
#  'RAM': 0    61+2
#  dtype: object,
#  'LM': 0    61+2
#  dtype: object,
#  'LCM': 0    58+2
#  dtype: object,
#  'CM': 0    58+2
#  dtype: object,
#  'RCM': 0    58+2
#  dtype: object,
#  'RM': 0    61+2
#  dtype: object,
#  'LWB': 0    61+2
#  dtype: object,
#  'LDM': 0    62+2
#  dtype: object,
#  'CDM': 0    62+2
#  dtype: object,
#  'RDM': 0    62+2
#  dtype: object,
#  'RWB': 0    61+2
#  dtype: object,
#  'LB': 0    64+2
#  dtype: object,
#  'LCB': 0    64+2
#  dtype: object,
#  'CB': 0    64+2
#  dtype: object,
#  'RCB': 0    64+2
#  dtype: object,
#  'RB': 0    64+2
#  dtype: object,
#  'value': 2481203.67102012}

# %%
def preprocessing(data):
    #Replace null value with mean at wage and value columns
    #split column 'position'
    data.update( data.loc[:, data.isnull().sum() < 0.25*data.shape[0]])
    #Replace null value with mean at wage and value columns
    #split column 'position'
    temp = []
    for i in data.loc[:,'positions']:
        l = i.split(',')
        temp.append(l[0])
    data.loc[:,'positions'] = temp
    temp.clear()
    for i in data.loc[:,'work_rate']:
        l = i.split('/')
        temp.append(l[0])
    data.loc[:,'work_rate'] = temp
      
    data['value'].fillna(value=mean_mode['value'], inplace=True)
    data['wage'].fillna(value=mean_mode['wage'], inplace=True)
    
    
    data.dropna(how='any',inplace=True)

    Columns=['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']
    for i in Columns:
        position(i,data)

    #Date encodig
    date_toInt(data,'contract_end_year')
    date_toInt(data,'birth_date')
    date_toInt(data,'club_join_date')
    return data


data = preprocessing(data)

# %%
categorical_columns_selector = selector(dtype_include=object)
categorical_columns = categorical_columns_selector(data)
frames =[ data[categorical_columns], data['value']]
l = data[categorical_columns]
l.insert(10,'value',data['value'])
###correlation for cat vars
# categorical_correlation = associations(
#        l, filename='categorical_correlation.png', figsize=(8, 10),)

# %%
#convert categories data to numbers

#cols=['nationality','positions','preferred_foot','work_rate','body_type','club_team','club_position']
data, encoders=Feature_Encoder(data,categorical_columns)

# %%
def preprocessing2(dt):
    
    #Drop columns which do not affect on our model
    dt=dt.drop(['id','name','full_name','birth_date'], axis = 1)
    return dt
data = preprocessing2(data)

# %%
#Split data
numerical_columns_selector = selector(dtype_exclude=object)
numerical_columns = numerical_columns_selector(data)
X=data[numerical_columns]
Y=data["value"]
#Get the correlation between the features
data=data.iloc[:,:]
corr = data.corr()
#Top 50% Correlation training features with the Value
top_feature = corr.index[abs(corr['value'])>0.46]
#Correlation plot
plt.subplots(figsize=(12, 8))
top_corr = data[top_feature].corr()
sns.heatmap(top_corr, annot=True)
plt.show()

# %%
top_feature = top_feature.delete(-1)
features = []
features.append(list(top_feature))
features.append(['reactions','composure','CM','RCM','ST','RS','CF','RF','CAM','RAM'])
# X.info
#X.insert(0,'club_team',data['club_team'])
features[0].append('club_team')
X = X[features[0]]


#Drop features that have high correlatin with other features 
X=X.drop(features[1], axis = 1)
# 
X.info
# Out:
# <bound method DataFrame.info of        overall_rating  potential      wage  international_reputation(1-5)  \
# 833                87         90  260000.0                              3
# 907                90         90  205000.0                              4
# 1513               87         87  250000.0                              3
# 1719               88         88  355000.0                              4
# 1941               88         88  130000.0                              4
# ...               ...        ...       ...                            ...
# 13202              88         91  255000.0                              4
# 13216              79         80   48000.0                              2
# 13242              68         68    5000.0                              1
# 13595              75         75   10000.0                              3
# 14061              87         87  115000.0                              3
#
#        release_clause_euro  club_rating  national_rating  finishing  \
# 833            132800000.0         86.0             85.0         79
# 907            127100000.0         85.0             77.0         91
# 1513            77900000.0         86.0             85.0         73
# 1719           123000000.0         86.0             75.0         86
# 1941            98600000.0         81.0             85.0         87
# ...                    ...          ...              ...        ...
# 13202          144200000.0         82.0             84.0         75
# 13216           24700000.0         76.0             78.0         34
# 13242            1800000.0         68.0             71.0         64
# 13595           10500000.0         69.0             74.0         75
# 14061           88400000.0         80.0             83.0         90
#
#        short_passing  volleys  ...  penalties    LS    LW    LF    RW   LAM  \
# 833               86       65  ...         76  79.0  86.0  85.0  86.0  88.0
# 907               83       89  ...         86  90.0  86.0  89.0  86.0  86.0
# 1513              84       60  ...         59  79.0  85.0  82.0  85.0  83.0
# 1719              85       85  ...         76  89.0  89.0  89.0  89.0  88.0
# 1941              86       90  ...         89  85.0  89.0  89.0  89.0  89.0
# ...              ...      ...  ...        ...   ...   ...   ...   ...   ...
# 13202             86       85  ...         82  84.0  85.0  86.0  85.0  87.0
# 13216             67       28  ...         75  58.0  50.0  55.0  50.0  55.0
# 13242             55       48  ...         61  68.0  64.0  65.0  64.0  62.0
# 13595             67       70  ...         75  76.0  70.0  73.0  70.0  71.0
# 14061             74       87  ...         78  87.0  82.0  85.0  82.0  81.0
#
#          LM   LCM    RM  club_team
# 833    85.0  85.0  85.0         52
# 907    84.0  80.0  84.0         26
# 1513   86.0  83.0  86.0         25
# 1719   88.0  83.0  88.0         52
# 1941   88.0  83.0  88.0         14
# ...     ...   ...   ...        ...
# 13202  86.0  87.0  86.0         41
# 13216  54.0  65.0  54.0         55
# 13242  65.0  61.0  65.0         13
# 13595  69.0  65.0  69.0         56
# 14061  80.0  73.0  80.0         35
#
# [118 rows x 27 columns]>

# %%
#Feature Selection

#Split the data to training and testing sets
time1 = t.time()
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20,shuffle=True,random_state=10)
X_train, X_test, Scaler = Preprocessing_Scaling(X_train, X_test)

###--------------model1--------- 
poly_features = PolynomialFeatures(degree=3)

# transforms the existing features to higher degree features.
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.fit_transform(X_test)

# fit the transformed features to Linear Regression
poly_model = linear_model.LinearRegression()
poly_model.fit(X_train_poly, y_train)
time2 = t.time()
print('training time ',time2-time1)
# predicting on training data-set
y_train_predicted = poly_model.predict(X_train_poly)
ypred=poly_model.predict(X_test_poly)
#print('Co-efficient of linear regression',poly_model.coef_)
#print('Intercept of linear regression model',poly_model.intercept_)
error = metrics.mean_squared_error(y_test, ypred)
print('Mean Square Error',error )
print('r2_score = ',r2_score(y_test,ypred))
print('accuracy1 = ', poly_model.score(X_test_poly, y_test)*100)
# Out:
# training time  0.04587841033935547
# Mean Square Error 153035406111130.5
# r2_score =  0.6984999185438612
# accuracy1 =  69.84999185438612

# %%
0.9956060308343475
# Mean Square Error 136597209323.66988
# training time  0.37200450897216797
# accuracy =  98.83076997234913
# The mean cross-validation accuracy is: 0.989 +/- 0.002
# Out:
# 0.9956060308343475

# %%
time1 = t.time()

model2 = linear_model.LinearRegression()
model2.fit(X_train, y_train)
prediction = model2.predict(X_test)
print('Mean Square Error', metrics.mean_squared_error(np.asarray(y_test), prediction))
print('accuracy = ', model2.score(X_test, y_test)*100)
print('r2_score = ',r2_score(y_test,prediction))
time2 = t.time()
print('training time ',time2-time1)
# Out:
# Mean Square Error 16124335106296.248
# accuracy =  96.82329176527679
# r2_score =  0.9682329176527679
# training time  0.002991199493408203

# %%
# Intercept of linear regression model 2555594.6156413397
# Mean Square Error 363483567620.4137
# training time  0.006981372833251953
# accuracy =  98.83076997234913

# %%
def fillnaa(df , columns):
    
    #handel cat vars
    #print(df.isnull().sum())
    for i in columns:
        df[i].fillna(value=mean_mode[i], inplace=True)
    #print(df.isnull().sum())
    return df
def testfile(path,features):
    #Split data
    df = getData(path)
    df = fillnaa(df ,features[0] )
    df.info()
    df = preprocessing(df)
    df.info()
    df = encoder_transform(df,encoders.keys(),encoders )
    df = preprocessing2(df)
    
    xx=df[features[0]]
    xx=xx.drop(features[1], axis = 1)
    yy=df["value"]
    print(yy)
    xx = Scaler.transform(xx)
    xx_poly = poly_features.transform(xx)
    y_pred1 = poly_model.predict(xx_poly)
    print('Predicted Value for DecisionTreeClassifierModel is : ' , y_pred1[:20])
    print('accuracy1 = ', poly_model.score(xx_poly, yy)*100)
    #print('Predicted class for DecisionTreeClassifierModel is : ' , Scaler.inverse_transform(y_pred1[:20]))
    #print(accuracy_score(yy, y_pred1))


testfile('player-test-samples1.csv',features)
# Out:
# Series([], Name: value, dtype: int64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12240/716662802.py in <module>
#      29
#      30
# ---> 31 testfile('player-test-samples1.csv',features)
#
# ~\AppData\Local\Temp/ipykernel_12240/716662802.py in testfile(path, features)
#      20     yy=df["value"]
#      21     print(yy)
# ---> 22     xx = Scaler.transform(xx)
#      23     xx_poly = poly_features.transform(xx)
#      24     y_pred1 = poly_model.predict(xx_poly)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     881
#     882         copy = copy if copy is not None else self.copy
# --> 883         X = self._validate_data(X, reset=False,
#     884                                 accept_sparse='csr', copy=copy,
#     885                                 estimator=self, dtype=FLOAT_DTYPES,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     724         n_samples = _num_samples(array)
#     725         if n_samples < ensure_min_samples:
# --> 726             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     727                              " minimum of %d is required%s."
#     728                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 27)) while a minimum of 1 is required by StandardScaler.

# %%
0    1200000
1     400000
2     375000
Name: value, dtype: int64
Predicted Value for DecisionTreeClassifierModel is :  [1174515.17678388  247089.98326577  309668.88030761]
# # initializing data to be stored in db
# # database
# db = {}
# db['model1'] = model1
# db['model2'] = model2
# db['encoders'] = encoders
# db['Top_features'] = top_feature
# db['Scaler'] = Scaler
# # Its important to use binary mode
# dbfile = open('Regression_model', 'ab')

# # source, destination
# pickle.dump(db, dbfile)                     
# dbfile.close()

# dbfile = open('examplePickle', 'rb')     
# db = pickle.load(dbfile)
# dbfile.close()
# DecisionTreeClassifierModel = db['model']
